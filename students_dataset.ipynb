# %%
import pandas as pd
df = pd.read_csv("students.csv.txt")

print(df)
print(df.columns)
print(df.isnull().sum())
print(df.shape)
print(df.head())
# Out:
#        Name  Math  Physics  Chemistry  Attendance
# 0     Aarav    88       76         91          92
# 1      Diya    95       89         94          98
# 2     Rohan    45       52         48          68
# 3     Sneha    78       81         74          85
# 4   Karthik    62       58         66          72
# 5     Meera    91       95         89          97
# 6    Aditya    39       44         41          60
# 7     Nisha    84       79         88          90
# 8     Varun    55       61         57          75
# 9     Pooja    73       69         80          82
# 10    Rahul    67       72         64          78
# 11   Ananya    98       96         99          99
# 12   Vikram    49       53         46          65
# 13   Ishita    87       85         90          93
# 14    Arjun    58       62         55          70
# Index(['Name', 'Math', 'Physics', 'Chemistry', 'Attendance'], dtype='object')
# Name          0
# Math          0
# Physics       0
# Chemistry     0
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/vidyansl18-ops/student-performance-analytics/main/students.csv"

df = pd.read_csv(url)

print(df)
