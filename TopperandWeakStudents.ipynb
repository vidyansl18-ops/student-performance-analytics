# %%
import pandas as pd
import numpy as np
df=pd.read_csv("students.txt")
print(df)
df["Total"] = df["Math"] + df["Physics"] + df["Chemistry"]

#Topper
topper=df.loc[df["Total"].idxmax()]
print("Topper Details")
print("Topper:",topper["Name"])
print("Attendance:",topper["Attendance"])
print()

#Weak Students
weakstudents=df[df["Total"]<150]["Name"]
print("Students with less attendance:\n",df[df["Attendance"]<75]["Name"])

weakinphy=df[df["Physics"]<60]["Name"]
weakinmath=df[df["Math"]<60]["Name"]
weakinchem=df[df["Chemistry"]<60]["Name"]
print("Students weak in Physics:\n",weakinphy)
print()
print("Students weak in Chemistry:\n",weakinchem)
print()
print("Weak Students:\n",weakstudents)
# Out:
#        Name  Math  Physics  Chemistry  Attendance
# 0     Aarav    88       76         91          92
# 1      Diya    95       89         94          98
# 2     Rohan    45       52         48          68
# 3     Sneha    78       81         74          85
# 4   Karthik    62       58         66          72
# 5     Meera    91       95         89          97
# 6    Aditya    39       44         41          60
# 7     Nisha    84       79         88          90
# 8     Varun    55       61         57          75
# 9     Pooja    73       69         80          82
# 10    Rahul    67       72         64          78
# 11   Ananya    98       96         99          99
# 12   Vikram    49       53         46          65
# 13   Ishita    87       85         90          93
# 14    Arjun    58       62         55          70
# Topper Details
# Topper: Ananya
# Attendance: 99
#
# Students with less attendance:
#  2       Rohan
# 4     Karthik
# 6      Aditya
# 12     Vikram
# 14      Arjun
# ...
